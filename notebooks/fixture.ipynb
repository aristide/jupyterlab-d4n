# %% [markdown]
# # Selector-integrity fixture
#
# `jlpm test:selectors` opens this notebook to reach the `notebook-open` state.
# It is committed on purpose: the harness used to *create* an `Untitled.ipynb`
# on every run, which left a trail of stray files in this directory and made the
# file-browser assertions depend on how many had accumulated.
#
# Opening a fixed file instead is deterministic and leaves nothing behind.
# Do not delete this, and do not save changes into it.
#
# ## Why the constructs below are here
#
# They are not decoration. `style/surfaces/markdown.css` depends on a fenced
# block, a blockquote, a table and a `kbd`, and every selector a stylesheet
# depends on has to match a real element for `test:selectors` to mean anything.
# They live in THIS file rather than a second fixture because the server root is
# this directory, so a new file would change the `file-browser` snapshot.
#
# > A blockquote. Two-pixel bar, secondary text.
#
# | Column A | Column B |
# | -------- | -------- |
# | one      | two      |
# | three    | four     |
#
# ```python
# def fenced(x):
#     return x + 1
# ```
#
# Press <kbd>Ctrl</kbd>+<kbd>C</kbd> to interrupt.

# %%
# A code cell, so the harness can reach .jp-Cell / .jp-InputArea / the cell toolbar.
1 + 1
